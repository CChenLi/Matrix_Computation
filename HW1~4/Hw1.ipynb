# %%
import numpy as np

# %%
import numpy.linalg as npla

# %%
X = np.round(np.random.rand(2,2))

# %%
print(X)
# Out:
# [[0. 0.]
#  [0. 0.]]

# %%
X = np.array([[4, -1],[-1, 4]])

# %%
print(X)
# Out:
# [[ 4 -1]
#  [-1  4]]

# %%
print(npla.eig(X))
# Out:
# (array([5., 3.]), array([[ 0.70710678,  0.70710678],
#        [-0.70710678,  0.70710678]]))
